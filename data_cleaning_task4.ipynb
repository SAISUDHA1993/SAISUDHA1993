# %% [markdown]
# <a href="https://colab.research.google.com/github/SAISUDHA1993/SAISUDHA1993/blob/main/data_cleaning_task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **DATA CLEANING**
#
# **About Dataset**
#
# **Context**
#
# Get data on master details of any company registered with Registrar of Companies (RoC). Data contains various information like Corporate Identification Number(CIN), Company Name, Company Status, Company Class, Company Category, Authorized Capital in INR, Paid-up Capital in INR, Date of Registration, Registered State, Registrar of Companies, Principal Business Activity, Registered Office Address and Sub Category.
#
# **Content**
#
# The registered_companies.csv file contains the details of all Indian companies ever registered in India from 1857 to 2020.
# # of rows - 1992170
# # of columns - 17
#
# **Columns**
#
# CORPORATE_ IDENTIFICATION_NUMBER - Corporate Identification Number sometimes referred to as CIN is a unique identification number which is assigned by the ROC (Registrar of Companies) of various states under the MCA (Ministry of Corporate Affairs).
#
# COMPANY_NAME - Name of the company.
#
# COMPANY_STATUS - The 'Status' tell the current state of the company. Whether it is active and operating or dormant or it has been struck off and closed. There are 13 such status that a company could be carrying.
#
# ACTV - Active
#
# NAEF - Not available for e-filing
#
# ULQD - Under liquidation
#
# AMAL - Amalgamated
#
# STOF - Strike off
#
# DISD - Dissolved
#
# CLLD - Converted to LLP and Dissolved
#
# UPSO - Under process of Striking Off
#
# CLLP - Converted to LLP
#
# LIQD - Liquidated
#
# DRMT - Dormant
#
# MLIQ - Vanished
#
# D455 - Dormant under section 455
#
# COMPANY_CLASS - Companies are primarily classified into private and public. Private companies or private limited companies are those companies that are closely-held and have less than 200 shareholders. Public companies are limited companies that have more than 200 shareholders and are listed on a stock exchange.
#
# Public
# Private
# Private (One Person Company)
#
# COMPANY_CATEGORY - The category of the company.
#
# Company limited by Shares
#
# Company Limited by Guarantee
#
# Unlimited Company
#
# COMPANY_SUB _CATEGORY - The sub-category of the company.
#
# Non-govt company
#
# State Govt company
#
# Subsidiary of Foreign Company
#
# Guarantee and Association comp
#
# Union Govt company
#
# DATE_OF_ REGISTRATION - Date of registration of the company.
#
# REGISTERED_STATE - State in which company was registered.
#
# AUTHORIZED_CAP - Authorized Capital of the company (INR)
#
# PAIDUP_CAPITAL - Paid Up Capital of the company (INR).
#
# INDUSTRIAL_CLASS - Industrial class of the company as per NIC 2004.
#
# PRINCIPAL_ BUSINESS_ACTIVITY AS PER_CIN - Principal Business Activity of the company as per CIN.
#
# REGISTERED_OFFICE _ADDRESS - Registered office address of the company.
#
# REGISTRAR_OF _COMPANIES - Registrar office of the company.
#
# EMAIL_ADDR - Email address of the companies owner/director.
#
# LATEST_YEAR _ANNUAL _RETURN - Annual return of the last year.
#
# LATEST_YEAR _FINANCIAL _STATEMENT - Financial Statement of the last year.
#
# Acknowledgements
# Source: Open Government Data (OGD) Platform India

# %% [markdown]
# **1 - Data Loading and Inspection**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/content/registered_companies.csv') # reading csv files

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136728 entries, 0 to 136727
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   CORPORATE_IDENTIFICATION_NUMBER         136728 non-null  object
#  1   COMPANY_NAME                            136728 non-null  object
#  2   COMPANY_STATUS                          136727 non-null  object
#  3   COMPANY_CLASS                           136199 non-null  object
#  4   COMPANY_CATEGORY                        136196 non-null  object
#  5   COMPANY_SUB_CATEGORY                    136196 non-null  object
#  6   DATE_OF_REGISTRATION                    136628 non-null  object
#  7   REGISTERED_STATE                        136727 non-null  object
#  8   AUTHORIZED_CAP                          136727 non-null  float64
#  9   PAIDUP_CAPITAL                          136727 non-null  float64
#  10  INDUSTRIAL_CLASS                        136219 non-null  object
#  11  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  136723 non-null  object
#  12  REGISTERED_OFFICE_ADDRESS               136300 non-null  object
#  13  REGISTRAR_OF_COMPANIES                  136040 non-null  object
#  14  EMAIL_ADDR                              104495 non-null  object
#  15  LATEST_YEAR_ANNUAL_RETURN               80666 non-null   object
#  16  LATEST_YEAR_FINANCIAL_STATEMENT         80927 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 17.7+ MB

# %% [markdown]
# **Info of the Data**

# %%
df
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER  \
# 0                               F01450
# 1                               F01518
# 2                               F01573
# 3                               F01802
# 4                               F01818
# ...                                ...
# 136723           U07010KA2002PTC031216
# 136724           U07010KA2002PTC031240
# 136725           U07010KA2002PTC031241
# 136726           U07010KA2002PTC031255
# 136727           U07010KA2002PTC031265
#
#                                    COMPANY_NAME COMPANY_STATUS COMPANY_CLASS  \
# 0                     NIKO RESOURCES LIMITED              ACTV           NaN
# 1           WORLDWIDE RESOURCES HOLDINGS LTD              ACTV           NaN
# 2             ATWOOD OCEANIC PACIFIC LIMITED              ACTV           NaN
# 3                         SOLVAY S A BELGIUM              NAEF           NaN
# 4               TATE AND LYLE INDUSTRIES LTD              ACTV           NaN
# ...                                         ...            ...           ...
# 136723   SRI BALAJI REALTORS PRIVATE LIMITED              ACTV       Private
# 136724    PALMCO ENTERPRISES PRIVATE LIMITED              STOF       Private
# 136725   AISHWARYA BUILDTECH PRIVATE LIMITED              STOF       Private
# 136726  ADARSHA REAL ESTATES PRIVATE LIMITED              ACTV       Private
# 136727            SAVERA RESIDENCY PRIVATE LIMI            NaN           NaN
#
#                  COMPANY_CATEGORY COMPANY_SUB_CATEGORY DATE_OF_REGISTRATION  \
# 0                             NaN                  NaN                  NaN
# 1                             NaN                  NaN           16-07-1998
# 2                             NaN                  NaN                  NaN
# 3                             NaN                  NaN           25-06-2001
# 4                             NaN                  NaN           25-07-2001
# ...                           ...                  ...                  ...
# 136723  Company limited by Shares     Non-govt company           14-11-2002
# 136724  Company limited by Shares     Non-govt company           20-11-2002
# 136725  Company limited by Shares     Non-govt company           21-11-2002
# 136726  Company limited by Shares     Non-govt company           22-11-2002
# 136727                        NaN                  NaN                  NaN
#
#        REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL INDUSTRIAL_CLASS  \
# 0               Gujarat             0.0             0.0              NaN
# 1               Gujarat             0.0             0.0              NaN
# 2               Gujarat             0.0             0.0              NaN
# 3               Gujarat             0.0             0.0              NaN
# 4               Gujarat             0.0             0.0              NaN
# ...                 ...             ...             ...              ...
# 136723        Karnataka      60000000.0        100000.0            07010
# 136724        Karnataka       1000000.0        990000.0            07010
# 136725        Karnataka       1000000.0       1000000.0            07010
# 136726        Karnataka        500000.0        500000.0            07010
# 136727              NaN             NaN             NaN              NaN
#
#        PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                        Agriculture & allied
# 1                        Agriculture & allied
# 2                        Agriculture & allied
# 3                        Agriculture & allied
# 4                        Agriculture & allied
# ...                                       ...
# 136723                   Agriculture & allied
# 136724                   Agriculture & allied
# 136725                   Agriculture & allied
# 136726                   Agriculture & allied
# 136727                                    NaN
#
#                                 REGISTERED_OFFICE_ADDRESS  \
# 0                         4TH FLOOR,LANDMARKRACE COURSE
# 1       403 3 6 322 MAHAVIR HOUSEBUSHEER BAGH HYDERGUD...
# 2       Quadrant 1, Plot Number 18, 2nd FloorSuman Tow...
# 3          Plot No. 3526 & 3527,GIDC Industrial Estate,
# 4                         24 ATMAJYOTI NAGARELLORA PARK
# ...                                                   ...
# 136723  FLAT NO. 2, FARAH PLAZA,INFANTRY ROAD,BANGALORE
# 136724  No.26, RICHES GARDEN, KALKERE MAIN ROAD,RAMAMU...
# 136725  NO.531, FLOOR NO.1FAIZ AVENUE, 11TH MAIN4TH BL...
# 136726  Door No.121, Ganesha Temple RoadNear IB Circle,
# 136727                                                NaN
#
#        REGISTRAR_OF_COMPANIES               EMAIL_ADDR  \
# 0                   ROC DELHI     SANJAY@NIKOINDIA.COM
# 1                   ROC DELHI                      NaN
# 2                   ROC DELHI          info@nangia.com
# 3                   ROC DELHI  amit.kumashi@solvay.com
# 4                   ROC DELHI                      NaN
# ...                       ...                      ...
# 136723          ROC BANGALORE         info@acspl.co.in
# 136724          ROC BANGALORE        palmco@dataone.in
# 136725          ROC BANGALORE                      NaN
# 136726          ROC BANGALORE    nanjanagowda@yahoo.in
# 136727                    NaN                      NaN
#
#        LATEST_YEAR_ANNUAL_RETURN LATEST_YEAR_FINANCIAL_STATEMENT
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 136723                31-03-2017                      31-03-2017
# 136724                31-03-2014                      31-03-2013
# 136725                       NaN                             NaN
# 136726                31-03-2019                      31-03-2019
# 136727                       NaN                             NaN
#
# [136728 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1992170 entries, 0 to 1992169
# Data columns (total 17 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   CORPORATE_IDENTIFICATION_NUMBER         object
#  1   COMPANY_NAME                            object
#  2   COMPANY_STATUS                          object
#  3   COMPANY_CLASS                           object
#  4   COMPANY_CATEGORY                        object
#  5   COMPANY_SUB_CATEGORY                    object
#  6   DATE_OF_REGISTRATION                    object
#  7   REGISTERED_STATE                        object
#  8   AUTHORIZED_CAP                          float64
#  9   PAIDUP_CAPITAL                          float64
#  10  INDUSTRIAL_CLASS                        object
#  11  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  object
#  12  REGISTERED_OFFICE_ADDRESS               object
#  13  REGISTRAR_OF_COMPANIES                  object
#  14  EMAIL_ADDR                              object
#  15  LATEST_YEAR_ANNUAL_RETURN               object
#  16  LATEST_YEAR_FINANCIAL_STATEMENT         object
# dtypes: float64(2), object(15)
# memory usage: 258.4+ MB

# %% [markdown]
# **Shape of the Data**

# %%
df.shape
# Out:
# (1992170, 17)

# %% [markdown]
# **Displaying Data Frames**

# %%
df.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER                         COMPANY_NAME  \
# 0                          F01450            NIKO RESOURCES LIMITED
# 1                          F01518  WORLDWIDE RESOURCES HOLDINGS LTD
# 2                          F01573    ATWOOD OCEANIC PACIFIC LIMITED
# 3                          F01802                SOLVAY S A BELGIUM
# 4                          F01818      TATE AND LYLE INDUSTRIES LTD
#
#   COMPANY_STATUS COMPANY_CLASS COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 0           ACTV           NaN              NaN                  NaN
# 1           ACTV           NaN              NaN                  NaN
# 2           ACTV           NaN              NaN                  NaN
# 3           NAEF           NaN              NaN                  NaN
# 4           ACTV           NaN              NaN                  NaN
#
#   DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                  NaN          Gujarat             0.0             0.0
# 1           16-07-1998          Gujarat             0.0             0.0
# 2                  NaN          Gujarat             0.0             0.0
# 3           25-06-2001          Gujarat             0.0             0.0
# 4           25-07-2001          Gujarat             0.0             0.0
#
#   INDUSTRIAL_CLASS PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0              NaN                   Agriculture & allied
# 1              NaN                   Agriculture & allied
# 2              NaN                   Agriculture & allied
# 3              NaN                   Agriculture & allied
# 4              NaN                   Agriculture & allied
#
#                            REGISTERED_OFFICE_ADDRESS REGISTRAR_OF_COMPANIES  \
# 0                    4TH FLOOR,LANDMARKRACE COURSE                ROC DELHI
# 1  403 3 6 322 MAHAVIR HOUSEBUSHEER BAGH HYDERGUD...              ROC DELHI
# 2  Quadrant 1, Plot Number 18, 2nd FloorSuman Tow...              ROC DELHI
# 3     Plot No. 3526 & 3527,GIDC Industrial Estate,                ROC DELHI
# 4                    24 ATMAJYOTI NAGARELLORA PARK                ROC DELHI
#
#                 EMAIL_ADDR LATEST_YEAR_ANNUAL_RETURN  \
# 0     SANJAY@NIKOINDIA.COM                       NaN
# 1                      NaN                       NaN
# 2          info@nangia.com                       NaN
# 3  amit.kumashi@solvay.com                       NaN
# 4                      NaN                       NaN
#
#   LATEST_YEAR_FINANCIAL_STATEMENT
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
df.tail()
# Out:
#         CORPORATE_IDENTIFICATION_NUMBER  \
# 1992165           U51109NL2000PTC006232
# 1992166           U51109NL2000PTC006233
# 1992167           U51109NL2000PTC006259
# 1992168           U74950NL1998PTC005463
# 1992169           U74990NL2016PTC008397
#
#                                               COMPANY_NAME COMPANY_STATUS  \
# 1992165  SCIENTIFIC ADVANCE INSTRUMENTS & EQUIPMENTS CO...           STOF
# 1992166  SUNSHINE INSTRUMENTS & EQUIPMENTS COMPANY PRIV...           STOF
# 1992167  STERN (INDIA) PLANTATION & MARKETING PRIVATE L...           STOF
# 1992168            T.A. NGULLIE FRUIT PRODUCTS PVT LTD.              STOF
# 1992169                       NAGA MART PRIVATE LIMITED              ACTV
#
#         COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 1992165       Private  Company limited by Shares     Non-govt company
# 1992166       Private  Company limited by Shares     Non-govt company
# 1992167       Private  Company limited by Shares     Non-govt company
# 1992168       Private  Company limited by Shares     Non-govt company
# 1992169       Private  Company limited by Shares     Non-govt company
#
#         DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 1992165           30-06-2000         Nagaland       1000000.0         20000.0
# 1992166           30-06-2000         Nagaland       1000000.0        200000.0
# 1992167           25-07-2000         Nagaland        200000.0          3000.0
# 1992168           09-07-1998         Nagaland       2500000.0             0.0
# 1992169           29-02-2016         Nagaland        500000.0        100000.0
#
#         INDUSTRIAL_CLASS             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 1992165            51109  Wholesale and retail trade repair of motor veh...
# 1992166            51109  Wholesale and retail trade repair of motor veh...
# 1992167            51109  Wholesale and retail trade repair of motor veh...
# 1992168            74950        Real estate renting and business activities
# 1992169            74990        Real estate renting and business activities
#
#                         REGISTERED_OFFICE_ADDRESS REGISTRAR_OF_COMPANIES  \
# 1992165    BEHIND TOWN COMMITTEE,MKALABARI ROAD             ROC SHILLONG
# 1992166                JAIN TEMPLE ROADDIMAPUR              ROC SHILLONG
# 1992167  RENGMA CHURCH BUILDINGKHERMAHALDIMAPUR             ROC SHILLONG
# 1992168       CHUMUKEDIME,BLOCK-3, DIST.KOHIMA.             ROC SHILLONG
# 1992169                    T.K Angami Complex,              ROC SHILLONG
#
#                       EMAIL_ADDR LATEST_YEAR_ANNUAL_RETURN  \
# 1992165                      NaN                       NaN
# 1992166                      NaN                       NaN
# 1992167                      NaN                       NaN
# 1992168        rks97cs@yahoo.com                       NaN
# 1992169  narolamongkum@gmail.com                31-03-2019
#
#         LATEST_YEAR_FINANCIAL_STATEMENT
# 1992165                             NaN
# 1992166                             NaN
# 1992167                             NaN
# 1992168                             NaN
# 1992169                      31-03-2019

# %% [markdown]
# **Basic Statistics of the data**

# %%
df.describe()
# Out:
#        AUTHORIZED_CAP  PAIDUP_CAPITAL
# count    1.992170e+06    1.992170e+06
# mean     4.238508e+07    2.434621e+07
# std      2.960562e+09    2.313154e+09
# min      0.000000e+00    0.000000e+00
# 25%      1.000000e+05    1.000000e+05
# 50%      5.000000e+05    1.000000e+05
# 75%      1.500000e+06    5.020000e+05
# max      1.850000e+12    1.699613e+12

# %% [markdown]
# **Finding no.of unique values from each column**

# %%
df.nunique() #This method calculates the number of unique values in each column. It's handy for understandingthe diversity of data in categorical columns.
# Out:
# CORPORATE_IDENTIFICATION_NUMBER           1992170
# COMPANY_NAME                              1986230
# COMPANY_STATUS                                 13
# COMPANY_CLASS                                   3
# COMPANY_CATEGORY                                3
# COMPANY_SUB_CATEGORY                            5
# DATE_OF_REGISTRATION                        27721
# REGISTERED_STATE                               36
# AUTHORIZED_CAP                               9080
# PAIDUP_CAPITAL                             144245
# INDUSTRIAL_CLASS                             8162
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN         17
# REGISTERED_OFFICE_ADDRESS                 1787716
# REGISTRAR_OF_COMPANIES                         26
# EMAIL_ADDR                                1048199
# LATEST_YEAR_ANNUAL_RETURN                     554
# LATEST_YEAR_FINANCIAL_STATEMENT               443
# dtype: int64

# %% [markdown]
# **Finding the count of unique values from each column**

# %%
df['LATEST_YEAR_ANNUAL_RETURN'].value_counts().head(10)
# Out:
# LATEST_YEAR_ANNUAL_RETURN
# 31-03-2019    756538
# 31-03-2018    111385
# 31-03-2017     46636
# 31-03-2014     38605
# 31-03-2016     35866
# 31-03-2013     34155
# 31-03-2015     31952
# 31-03-2010     21566
# 31-03-2012     19288
# 31-03-2011     19054
# Name: count, dtype: int64

# %% [markdown]
# **Finding stats for a specific column**

# %%
df.LATEST_YEAR_ANNUAL_RETURN.mode()
# Out:
# 0    31-03-2019
# Name: LATEST_YEAR_ANNUAL_RETURN, dtype: object

# %% [markdown]
# **Handling Missing Data**
#
# **Check Missing Data in a Column**

# %%
df.isna()
# Out:
#          CORPORATE_IDENTIFICATION_NUMBER  COMPANY_NAME  COMPANY_STATUS  \
# 0                                  False         False           False
# 1                                  False         False           False
# 2                                  False         False           False
# 3                                  False         False           False
# 4                                  False         False           False
# ...                                  ...           ...             ...
# 1992165                            False         False           False
# 1992166                            False         False           False
# 1992167                            False         False           False
# 1992168                            False         False           False
# 1992169                            False         False           False
#
#          COMPANY_CLASS  COMPANY_CATEGORY  COMPANY_SUB_CATEGORY  \
# 0                 True              True                  True
# 1                 True              True                  True
# 2                 True              True                  True
# 3                 True              True                  True
# 4                 True              True                  True
# ...                ...               ...                   ...
# 1992165          False             False                 False
# 1992166          False             False                 False
# 1992167          False             False                 False
# 1992168          False             False                 False
# 1992169          False             False                 False
#
#          DATE_OF_REGISTRATION  REGISTERED_STATE  AUTHORIZED_CAP  \
# 0                        True             False           False
# 1                       False             False           False
# 2                        True             False           False
# 3                       False             False           False
# 4                       False             False           False
# ...                       ...               ...             ...
# 1992165                 False             False           False
# 1992166                 False             False           False
# 1992167                 False             False           False
# 1992168                 False             False           False
# 1992169                 False             False           False
#
#          PAIDUP_CAPITAL  INDUSTRIAL_CLASS  \
# 0                 False              True
# 1                 False              True
# 2                 False              True
# 3                 False              True
# 4                 False              True
# ...                 ...               ...
# 1992165           False             False
# 1992166           False             False
# 1992167           False             False
# 1992168           False             False
# 1992169           False             False
#
#          PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  REGISTERED_OFFICE_ADDRESS  \
# 0                                         False                      False
# 1                                         False                      False
# 2                                         False                      False
# 3                                         False                      False
# 4                                         False                      False
# ...                                         ...                        ...
# 1992165                                   False                      False
# 1992166                                   False                      False
# 1992167                                   False                      False
# 1992168                                   False                      False
# 1992169                                   False                      False
#
#          REGISTRAR_OF_COMPANIES  EMAIL_ADDR  LATEST_YEAR_ANNUAL_RETURN  \
# 0                         False       False                       True
# 1                         False        True                       True
# 2                         False       False                       True
# 3                         False       False                       True
# 4                         False        True                       True
# ...                         ...         ...                        ...
# 1992165                   False        True                       True
# 1992166                   False        True                       True
# 1992167                   False        True                       True
# 1992168                   False       False                       True
# 1992169                   False       False                      False
#
#          LATEST_YEAR_FINANCIAL_STATEMENT
# 0                                   True
# 1                                   True
# 2                                   True
# 3                                   True
# 4                                   True
# ...                                  ...
# 1992165                             True
# 1992166                             True
# 1992167                             True
# 1992168                             True
# 1992169                            False
#
# [1992170 rows x 17 columns]

# %% [markdown]
# Applying the .isna() method for a column will return the boolean list with True for the indiceswhere there is a missing value.
#
# And passing this list to a dataframe will return the rows where that column values are null

# %% [markdown]
# **To Find the count of missing values in each column**

# %%
df.isna().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER                0
# COMPANY_NAME                                   0
# COMPANY_STATUS                                 0
# COMPANY_CLASS                               5078
# COMPANY_CATEGORY                            5085
# COMPANY_SUB_CATEGORY                        5090
# DATE_OF_REGISTRATION                        2525
# REGISTERED_STATE                               0
# AUTHORIZED_CAP                                 0
# PAIDUP_CAPITAL                                 0
# INDUSTRIAL_CLASS                            4811
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN        12
# REGISTERED_OFFICE_ADDRESS                  15259
# REGISTRAR_OF_COMPANIES                     42198
# EMAIL_ADDR                                370208
# LATEST_YEAR_ANNUAL_RETURN                 831317
# LATEST_YEAR_FINANCIAL_STATEMENT           828829
# dtype: int64

# %%
#checking the percentage of missing values for each column
round((df.isna().sum()/df.shape[0])*100)
# Out:
# CORPORATE_IDENTIFICATION_NUMBER            0.0
# COMPANY_NAME                               0.0
# COMPANY_STATUS                             0.0
# COMPANY_CLASS                              0.0
# COMPANY_CATEGORY                           0.0
# COMPANY_SUB_CATEGORY                       0.0
# DATE_OF_REGISTRATION                       0.0
# REGISTERED_STATE                           0.0
# AUTHORIZED_CAP                             0.0
# PAIDUP_CAPITAL                             0.0
# INDUSTRIAL_CLASS                           0.0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN     0.0
# REGISTERED_OFFICE_ADDRESS                  0.0
# REGISTRAR_OF_COMPANIES                     0.0
# EMAIL_ADDR                                22.0
# LATEST_YEAR_ANNUAL_RETURN                 40.0
# LATEST_YEAR_FINANCIAL_STATEMENT           40.0
# dtype: float64

# %% [markdown]
# As we didnot see any value percentage exceeds more than 50% we decide not to remove the column and we will move forward.

# %% [markdown]
# find duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CORPORATE_IDENTIFICATION_NUMBER, COMPANY_NAME, COMPANY_STATUS, COMPANY_CLASS, COMPANY_CATEGORY, COMPANY_SUB_CATEGORY, DATE_OF_REGISTRATION, REGISTERED_STATE, AUTHORIZED_CAP, PAIDUP_CAPITAL, INDUSTRIAL_CLASS, PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, REGISTERED_OFFICE_ADDRESS, REGISTRAR_OF_COMPANIES, EMAIL_ADDR, LATEST_YEAR_ANNUAL_RETURN, LATEST_YEAR_FINANCIAL_STATEMENT]
# Index: []

# %% [markdown]
# we don't have any duplicate values in our dataset , if duplicates existed we would be removing those by using the command'
# df.drop_duplicates()

# %% [markdown]
# Identifying the garbage values in the object columns

# %%
for i in df.select_dtypes(include='object').columns:
    print(df[i].value_counts())
    print('****'*10)
# Out:
# CORPORATE_IDENTIFICATION_NUMBER
# F01450                   1
# U51500GJ1998PTC034891    1
# U51498GJ2009PTC057262    1
# U51498GJ2012PTC070005    1
# U51498GJ2013PTC074103    1
#                         ..
# U29305GJ2018PTC105286    1
# U29305GJ2019FTC109924    1
# U29305GJ2019PTC106810    1
# U29305GJ2019PTC109582    1
# U80211GJ2012PTC072806    1
# Name: count, Length: 56687, dtype: int64
# ****************************************
# COMPANY_NAME
# GEOGLOBAL RESOURCES (BARBADOS) INC.             3
# MOLY METAL PRIVATE LIMITED                      3
# WELSPUN ENTERPRISES LIMITED                     2
# DREAM LAND GYMKHANA PRIVATE LIMITED             2
# DINESH CHEMICALS PVT LTD                        2
#                                                ..
# ENGGTEMP INNOVATION PRIVATE LIMITED             1
# POOJA ELEVATOR GEAR (INDIA) PRIVATELIMITED      1
# STANDARD CAL-TEST PRIVATE LIMITED               1
# OMNIBRX BIOTECHNOLOGIES PRIVATE LIMITED         1
# VISION LITERACY PRIVATE LIMITED                 1
# Name: count, Length: 56635, dtype: int64
# ****************************************
# COMPANY_STATUS
# ACTV    35636
# STOF    17392
# UPSO     1597
# AMAL      916
# CLLP      435
# ULQD      296
# CLLD      179
# NAEF      147
# DISD       60
# D455       29
# Name: count, dtype: int64
# ****************************************
# COMPANY_CLASS
# Private                        50973
# Public                          5123
# Private(One Person Company)      516
# Name: count, dtype: int64
# ****************************************
# COMPANY_CATEGORY
# Company limited by Shares       55071
# Company Limited by Guarantee     1463
# Unlimited Company                  78
# Name: count, dtype: int64
# ****************************************
# COMPANY_SUB_CATEGORY
# Non-govt company                  55744
# Guarantee and Association comp      593
# Subsidiary of Foreign Company       209
# State Govt company                   62
# Union Govt company                    4
# Name: count, dtype: int64
# ****************************************
# DATE_OF_REGISTRATION
# 20-09-2018    82
# 18-05-1995    35
# 19-09-2018    32
# 19-12-2019    31
# 22-05-2017    30
#               ..
# 26-08-1971     1
# 21-12-1971     1
# 04-09-1972     1
# 16-09-1972     1
# 13-01-1982     1
# Name: count, Length: 10581, dtype: int64
# ****************************************
# REGISTERED_STATE
# Gujarat    56687
# Name: count, dtype: int64
# ****************************************
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN
# Manufacturing                                                                                                     25412
# Real estate renting and business activities                                                                       11465
# Construction                                                                                                       3936
# Agriculture & allied                                                                                               2770
# Other community social and personal service activities                                                             2702
# Transport storage and communications                                                                               2608
# Wholesale and retail trade repair of motor vehicles motorcycles and personal and household goods                   2410
# Hotels and restaurants                                                                                             1642
# Extraterritorial organizations and bodies                                                                          1310
# Mining and quarrying                                                                                                882
# Financial intermediation                                                                                            648
# Health and social work                                                                                              613
# Electricity gas and water supply                                                                                    120
# Education                                                                                                            88
# Unclassified                                                                                                         36
# Public administration and defence compulsory social security                                                         34
# Activities of private households as employers and undifferentiated production activities of private households       11
# Name: count, dtype: int64
# ****************************************
# REGISTERED_OFFICE_ADDRESS
# 4,SHRI GHANSHYAM PARK CO OP- H SOC. LTD, B/HPARASKUNJ SOC., SATELLITE ROAD, JODHPUR,      30
# 3rd Floor, Sarthik Annexe, Nr. Fun Republic CinemaSatellite Road, Satellite               22
# KCL, NEAR 150 FEET RING ROAD, AMIN MARG JUNCTIONAMIN MARG                                 19
# Office 25, 2nd Floor, Ascon CityCity light Road                                           17
# 071 , A-8 , GOYAL INTERCITYOPP DOOR DARSHAN TOWER , THALTEJ                               14
#                                                                                           ..
# SHOP NO.1, 1ST FLOOR, ANANT CHAMBERM. G. ROAD,                                             1
# 534-536, JIMMY TOWER, GONDAL ROADNEAR BRIDGE                                               1
# C/1,2,3,4,5, MARUTI INDUSTRIAL ESTATEGIDC PHASE-1, NR CHOKSI TUBE, VATVA                   1
# 5 PANKAJ IND. ESTATEOPP. GUJARAT BOTTLING, RAKHIAL                                         1
# 205, KEYU COMPLEX,  NEAR HEAD POST OFFICE,HARIHAR CHOWK,                                   1
# Name: count, Length: 54662, dtype: int64
# ****************************************
# REGISTRAR_OF_COMPANIES
# ROC AHMEDABAD    56355
# ROC DELHI           70
# ROC GOA              5
# Name: count, dtype: int64
# ****************************************
# EMAIL_ADDR
# dpopatassociates@gmail.com    89
# k_dalal@rediffmail.com        56
# roc@krutesh.ca                53
# mcafiling@yahoo.co.in         49
# admin@langalia.com            45
#                               ..
# shap_sym@yahoo.com             1
# jaydivyesh@gmail.com           1
# hnmh@hotmail.com               1
# xpertcircuit@gmail.com         1
# mehta_madhu@hotmail.com        1
# Name: count, Length: 34714, dtype: int64
# ****************************************
# LATEST_YEAR_ANNUAL_RETURN
# 31-03-2019    24133
# 31-03-2018     2462
# 31-03-2017     1138
# 31-03-2014      935
# 31-03-2015      874
# 31-03-2016      863
# 31-03-2013      827
# 31-03-2010      507
# 31-03-2012      473
# 31-03-2011      466
# 31-03-2009      379
# 31-03-2006      365
# 31-03-2007      251
# 31-03-2008      249
# 31-03-2005       34
# 30-09-2013       18
# 31-12-2018       15
# 30-09-2006        7
# 30-09-2010        5
# 30-09-2009        5
# 30-06-2007        4
# 30-09-2008        4
# 31-12-2010        3
# 30-09-2011        3
# 31-03-2003        3
# 28-07-2008        3
# 31-03-2004        3
# 30-09-2014        3
# 30-03-2019        3
# 30-06-2009        2
# 01-04-2019        2
# 30-06-2006        2
# 30-06-2011        2
# 31-12-2008        2
# 31-12-2014        2
# 31-12-2005        2
# 30-06-2013        2
# 28-09-2014        1
# 22-05-2009        1
# 15-07-2006        1
# 31-12-2006        1
# 31-12-2012        1
# 14-08-2006        1
# 30-03-2008        1
# 31-08-2018        1
# 30-03-2006        1
# 26-03-2014        1
# 25-09-2013        1
# 30-06-2010        1
# 01-04-2012        1
# 30-09-2019        1
# 28-09-2013        1
# 22-09-2008        1
# 31-05-2015        1
# 17-08-2007        1
# 30-06-2012        1
# 31-12-2011        1
# 30-09-2000        1
# 31-03-2           1
# Name: count, dtype: int64
# ****************************************
# LATEST_YEAR_FINANCIAL_STATEMENT
# 31-03-2019    24274
# 31-03-2018     2477
# 31-03-2017     1122
# 31-03-2014      918
# 31-03-2015      873
# 31-03-2016      868
# 31-03-2013      851
# 31-03-2010      520
# 31-03-2011      482
# 31-03-2012      473
# 31-03-2009      396
# 31-03-2006      384
# 31-03-2008      255
# 31-03-2007      240
# 31-03-2005       26
# 31-12-2018       15
# 30-03-2006        7
# 30-09-2013        5
# 28-07-2008        3
# 31-12-2010        3
# 30-06-2006        3
# 31-12-2014        3
# 30-03-2005        3
# 31-03-2004        3
# 30-06-2009        2
# 31-03-2003        2
# 31-12-2008        2
# 30-09-2010        2
# 30-09-2008        2
# 30-06-2011        2
# 30-06-2013        2
# 30-06-2012        1
# 31-08-2018        1
# 31-08-2005        1
# 31-12-2012        1
# 30-09-2006        1
# 31-12-2006        1
# 30-09-2002        1
# 30-12-2005        1
# 31-12-2011        1
# 30-03-2016        1
# 30-06-2010        1
# 01-07-2005        1
# 30-06-2007        1
# 30-03-2003        1
# Name: count, dtype: int64
# ****************************************

# %%
sns.boxplot(x=df['AUTHORIZED_CAP'])
# Out:
# <Axes: xlabel='AUTHORIZED_CAP'>

# %%
# Calculate IQR
Q1 = np.percentile(df['AUTHORIZED_CAP'], 25)
Q3 = np.percentile(df['AUTHORIZED_CAP'], 75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
filtered_data = df[(df['AUTHORIZED_CAP'] >= (Q1 - 1.5 * IQR)) & (df['AUTHORIZED_CAP'] <= (Q3 + 1.5 * IQR))]

# %%
sns.boxplot(x=filtered_data['AUTHORIZED_CAP'])
plt.show()

# %%
df.shape
# Out:
# (67622, 17)

# %%
df.describe()
# Out:
#        AUTHORIZED_CAP  PAIDUP_CAPITAL  INDUSTRIAL_CLASS
# count    6.762100e+04    6.762100e+04      67551.000000
# mean     9.244841e+07    4.648991e+07      44705.935042
# std      4.212328e+09    2.904743e+09      25603.834591
# min      0.000000e+00    0.000000e+00          0.000000
# 25%      1.000000e+05    1.000000e+05      24921.500000
# 50%      5.000000e+05    1.000000e+05      36100.000000
# 75%      2.500000e+06    1.000000e+06      72200.000000
# max      6.000000e+11    5.901303e+11      99999.000000

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#       CORPORATE_IDENTIFICATION_NUMBER  \
# 0                              F01450
# 1                              F01518
# 2                              F01573
# 3                              F01802
# 4                              F01818
# ...                               ...
# 67617           U17119GJ1993PTC020052
# 67618           U17119GJ1993PTC020053
# 67619           U17119GJ1993PTC020054
# 67620           U17119GJ1993PTC020059
# 67621           U17119GJ1993PTC020061
#
#                                             COMPANY_NAME COMPANY_STATUS  \
# 0                              NIKO RESOURCES LIMITED              ACTV
# 1                    WORLDWIDE RESOURCES HOLDINGS LTD              ACTV
# 2                      ATWOOD OCEANIC PACIFIC LIMITED              ACTV
# 3                                  SOLVAY S A BELGIUM              NAEF
# 4                        TATE AND LYLE INDUSTRIES LTD              ACTV
# ...                                                  ...            ...
# 67617                       SHABRI SYNTHETICS PVT LTD              STOF
# 67618  SHANTIPRAKASH DYEING AND PRINTING MILLSPRIVATE...           ACTV
# 67619               SAKET TEXTURISERS PRIVATE LIMITED              ACTV
# 67620                    ANKIT TEXPIN PRIVATE LIMITED              ACTV
# 67621                       NEKVEE SYNTHETICS PVT LTD              ACTV
#
#       COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 0               NaN                        NaN                  NaN
# 1               NaN                        NaN                  NaN
# 2               NaN                        NaN                  NaN
# 3               NaN                        NaN                  NaN
# 4               NaN                        NaN                  NaN
# ...             ...                        ...                  ...
# 67617       Private  Company limited by Shares     Non-govt company
# 67618       Private  Company limited by Shares     Non-govt company
# 67619       Private  Company limited by Shares     Non-govt company
# 67620       Private  Company limited by Shares     Non-govt company
# 67621       Private  Company limited by Shares     Non-govt company
#
#       DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                      NaN          Gujarat             0.0             0.0
# 1               16-07-1998          Gujarat             0.0             0.0
# 2                      NaN          Gujarat             0.0             0.0
# 3               25-06-2001          Gujarat             0.0             0.0
# 4               25-07-2001          Gujarat             0.0             0.0
# ...                    ...              ...             ...             ...
# 67617           23-08-1993          Gujarat        500000.0             0.0
# 67618           23-08-1993          Gujarat       7500000.0       5428180.0
# 67619           23-08-1993          Gujarat       1500000.0       1352500.0
# 67620           23-08-1993          Gujarat       8500000.0       4000000.0
# 67621           24-08-1993              NaN             NaN             NaN
#
#        INDUSTRIAL_CLASS PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                   NaN                   Agriculture & allied
# 1                   NaN                   Agriculture & allied
# 2                   NaN                   Agriculture & allied
# 3                   NaN                   Agriculture & allied
# 4                   NaN                   Agriculture & allied
# ...                 ...                                    ...
# 67617           17119.0                          Manufacturing
# 67618           17119.0                          Manufacturing
# 67619           17119.0                          Manufacturing
# 67620           17119.0                          Manufacturing
# 67621               NaN                                    NaN
#
#                                REGISTERED_OFFICE_ADDRESS  \
# 0                        4TH FLOOR,LANDMARKRACE COURSE
# 1      403 3 6 322 MAHAVIR HOUSEBUSHEER BAGH HYDERGUD...
# 2      Quadrant 1, Plot Number 18, 2nd FloorSuman Tow...
# 3         Plot No. 3526 & 3527,GIDC Industrial Estate,
# 4                        24 ATMAJYOTI NAGARELLORA PARK
# ...                                                  ...
# 67617  260/2B,GIDC OPP.G.TEX PRINTSPVT LTD.PANDESARAS...
# 67618                  PLOT NO A-494 G I D CPANDESARA
# 67619                   47/219, KARANS ROAD,TAL-MANDVI
# 67620  Survey No. 273,Siddhivinayak Petroleum Compoun...
# 67621                                                NaN
#
#       REGISTRAR_OF_COMPANIES                   EMAIL_ADDR  \
# 0                  ROC DELHI         SANJAY@NIKOINDIA.COM
# 1                  ROC DELHI                          NaN
# 2                  ROC DELHI              info@nangia.com
# 3                  ROC DELHI      amit.kumashi@solvay.com
# 4                  ROC DELHI                          NaN
# ...                      ...                          ...
# 67617          ROC AHMEDABAD                          NaN
# 67618          ROC AHMEDABAD  shanti_prakash123@yahoo.com
# 67619          ROC AHMEDABAD         rylsurat@hotmail.com
# 67620          ROC AHMEDABAD          sgp_daman@yahoo.com
# 67621                    NaN                          NaN
#
#       LATEST_YEAR_ANNUAL_RETURN LATEST_YEAR_FINANCIAL_STATEMENT
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
# ...                         ...                             ...
# 67617                       NaN                             NaN
# 67618                31-03-2019                      31-03-2019
# 67619                31-03-2018                      31-03-2018
# 67620                31-03-2019                      31-03-2019
# 67621                       NaN                             NaN
#
# [67622 rows x 17 columns]

# %%
print(df.columns)
# Out:
# Index(['CORPORATE_IDENTIFICATION_NUMBER', 'COMPANY_NAME', 'COMPANY_STATUS',
#        'COMPANY_CLASS', 'COMPANY_CATEGORY', 'COMPANY_SUB_CATEGORY',
#        'DATE_OF_REGISTRATION', 'REGISTERED_STATE', 'AUTHORIZED_CAP',
#        'PAIDUP_CAPITAL', 'INDUSTRIAL_CLASS',
#        'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', 'REGISTERED_OFFICE_ADDRESS',
#        'REGISTRAR_OF_COMPANIES', 'EMAIL_ADDR', 'LATEST_YEAR_ANNUAL_RETURN',
#        'LATEST_YEAR_FINANCIAL_STATEMENT'],
#       dtype='object')

# %%
sns.boxplot(x=df['PAIDUP_CAPITAL'])
# Out:
# <Axes: xlabel='PAIDUP_CAPITAL'>

# %%
# Calculate IQR
Q1 = np.percentile(df['PAIDUP_CAPITAL'], 25)
Q3 = np.percentile(df['PAIDUP_CAPITAL'], 75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
filtereddata = df[(df['PAIDUP_CAPITAL'] >= (Q1 - 1.5 * IQR)) & (df['PAIDUP_CAPITAL'] <= (Q3 + 1.5 * IQR))]

# %%
sns.boxplot(x=filtereddata['PAIDUP_CAPITAL'])
plt.show()

# %%
df.shape
# Out:
# (67622, 17)

# %%
df.isnull()
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER  COMPANY_NAME  COMPANY_STATUS  \
# 0                                False         False           False
# 1                                False         False           False
# 2                                False         False           False
# 3                                False         False           False
# 4                                False         False           False
# ...                                ...           ...             ...
# 94970                            False         False           False
# 94971                            False         False           False
# 94972                            False         False           False
# 94973                            False         False           False
# 94974                            False         False           False
#
#        COMPANY_CLASS  COMPANY_CATEGORY  COMPANY_SUB_CATEGORY  \
# 0               True              True                  True
# 1               True              True                  True
# 2               True              True                  True
# 3               True              True                  True
# 4               True              True                  True
# ...              ...               ...                   ...
# 94970          False             False                 False
# 94971          False             False                 False
# 94972          False             False                 False
# 94973          False             False                 False
# 94974          False             False                 False
#
#        DATE_OF_REGISTRATION  REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                      True             False           False           False
# 1                     False             False           False           False
# 2                      True             False           False           False
# 3                     False             False           False           False
# 4                     False             False           False           False
# ...                     ...               ...             ...             ...
# 94970                 False             False           False           False
# 94971                 False             False           False           False
# 94972                 False             False           False           False
# 94973                 False             False           False           False
# 94974                 False             False           False           False
#
#        INDUSTRIAL_CLASS  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                  True                                   False
# 1                  True                                   False
# 2                  True                                   False
# 3                  True                                   False
# 4                  True                                   False
# ...                 ...                                     ...
# 94970             False                                   False
# 94971             False                                   False
# 94972             False                                   False
# 94973             False                                   False
# 94974             False                                   False
#
#        REGISTERED_OFFICE_ADDRESS  REGISTRAR_OF_COMPANIES  EMAIL_ADDR  \
# 0                          False                   False       False
# 1                          False                   False        True
# 2                          False                   False       False
# 3                          False                   False       False
# 4                          False                   False        True
# ...                          ...                     ...         ...
# 94970                      False                   False        True
# 94971                      False                   False        True
# 94972                      False                   False        True
# 94973                      False                   False       False
# 94974                      False                    True        True
#
#        LATEST_YEAR_ANNUAL_RETURN  LATEST_YEAR_FINANCIAL_STATEMENT
# 0                           True                             True
# 1                           True                             True
# 2                           True                             True
# 3                           True                             True
# 4                           True                             True
# ...                          ...                              ...
# 94970                       True                             True
# 94971                       True                             True
# 94972                       True                             True
# 94973                      False                            False
# 94974                       True                             True
#
# [94975 rows x 17 columns]

# %%
#extract the column names
cols = df.columns

#plot a heatmap of missing values with seaborn
plt.figure(figsize = (10,5))
sns.heatmap(df[cols].isnull())
# Out:
# <Axes: >

# %%
#Get the percentage of missing values in each column
missing_pct = round(df.isnull().sum()/len(df) * 100, 1)
print(missing_pct)
# Out:
# CORPORATE_IDENTIFICATION_NUMBER            0.0
# COMPANY_NAME                               0.0
# COMPANY_STATUS                             0.0
# COMPANY_CLASS                              0.1
# COMPANY_CATEGORY                           0.1
# COMPANY_SUB_CATEGORY                       0.1
# DATE_OF_REGISTRATION                       0.0
# REGISTERED_STATE                           0.0
# AUTHORIZED_CAP                             0.0
# PAIDUP_CAPITAL                             0.0
# INDUSTRIAL_CLASS                           0.1
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN     0.0
# REGISTERED_OFFICE_ADDRESS                  0.3
# REGISTRAR_OF_COMPANIES                     0.6
# EMAIL_ADDR                                22.6
# LATEST_YEAR_ANNUAL_RETURN                 39.2
# LATEST_YEAR_FINANCIAL_STATEMENT           39.0
# dtype: float64

# %%
#columns with more than 30% missing values
drop_cols = missing_pct[missing_pct > 30].index
#We can drop these columns with greater than 30 percent missing values
df_new = df.drop(columns = drop_cols)

#Extract columns with mising values between 1 and 30%
replace_cols = missing_pct[(missing_pct > 0) & (missing_pct < 30)].index

#Iterate to replace missing values
for col in replace_cols:
    # if column is year built we replace with median otherwise the mean
    if col == "AUTHORIZED_CAP":
        df_new.fillna(df_new[col].median(), inplace=True)
    elif df_new[col].dtype != 'object': # Check if the column is numeric
        mean_value = df_new[col].mean()
        df_new.fillna(mean_value, inplace=True)
    # Handle non-numeric columns (e.g., fill with mode or a constant)
    else:
        #mode_value = df_new[col].mode()[0]  # Calculate the mode
        #df_new[col].fillna(mode_value, inplace=True)  # Fill with mode
        df_new[col].fillna('nodata', inplace=True)
        df_new['EMAIL_ADDR'].fillna('nodata', inplace=True)
        df_new['REGISTRAR_OF_COMPANIES'].fillna('nodata', inplace=True)
        df_new['DATE_OF_REGISTRATION'] = pd.to_datetime(df_new['DATE_OF_REGISTRATION'])
        df_new['DATE_OF_REGISTRATION'] = df_new.groupby('COMPANY_CATEGORY')['DATE_OF_REGISTRATION'].transform(lambda x: x.fillna(x.mean()))

df_new.isnull().sum()  # preview for missing values
# Out:
# <ipython-input-23-cb2507c204fc>:24: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_new['DATE_OF_REGISTRATION'] = pd.to_datetime(df_new['DATE_OF_REGISTRATION'])
# <ipython-input-23-cb2507c204fc>:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '45070.853211105845' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df_new.fillna(mean_value, inplace=True)
# CORPORATE_IDENTIFICATION_NUMBER           0
# COMPANY_NAME                              0
# COMPANY_STATUS                            0
# COMPANY_CLASS                             0
# COMPANY_CATEGORY                          0
# COMPANY_SUB_CATEGORY                      0
# DATE_OF_REGISTRATION                      0
# REGISTERED_STATE                          0
# AUTHORIZED_CAP                            0
# PAIDUP_CAPITAL                            0
# INDUSTRIAL_CLASS                          0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN    0
# REGISTERED_OFFICE_ADDRESS                 0
# REGISTRAR_OF_COMPANIES                    0
# EMAIL_ADDR                                0
# dtype: int64

# %%
df_new
# Out:
#       CORPORATE_IDENTIFICATION_NUMBER                           COMPANY_NAME  \
# 0                              F01450              NIKO RESOURCES LIMITED
# 1                              F01518    WORLDWIDE RESOURCES HOLDINGS LTD
# 2                              F01573      ATWOOD OCEANIC PACIFIC LIMITED
# 3                              F01802                  SOLVAY S A BELGIUM
# 4                              F01818        TATE AND LYLE INDUSTRIES LTD
# ...                               ...                                    ...
# 94970           U65910GJ1983PTC006471  SUBHJAVI EXPORTERS PRIVATE LIMITED
# 94971           U65910GJ1983PTC006505     ABHILASH STOCK HOLDINGS PVT LTD
# 94972           U65910GJ1983PTC006510               URMIL EXPORTS PVT LTD
# 94973           U65910GJ1983PTC006519  ANVAYA INVESTMENTS PRIVATE LIMITED
# 94974           U65910GJ1983PTC006521        ADHINAMI INVESTMENTS PVT LTD
#
#       COMPANY_STATUS COMPANY_CLASS           COMPANY_CATEGORY  \
# 0               ACTV        nodata                     nodata
# 1               ACTV        nodata                     nodata
# 2               ACTV        nodata                     nodata
# 3               NAEF        nodata                     nodata
# 4               ACTV        nodata                     nodata
# ...              ...           ...                        ...
# 94970           STOF       Private  Company limited by Shares
# 94971           UPSO       Private  Company limited by Shares
# 94972           ACTV       Private  Company limited by Shares
# 94973           ACTV       Private  Company limited by Shares
# 94974           ACTV       Private  Company limited by Shares
#
#       COMPANY_SUB_CATEGORY          DATE_OF_REGISTRATION REGISTERED_STATE  \
# 0                   nodata 1970-01-01 00:00:00.000045070          Gujarat
# 1                   nodata 1970-01-01 00:00:00.000045070          Gujarat
# 2                   nodata 1970-01-01 00:00:00.000045070          Gujarat
# 3                   nodata 1970-01-01 00:00:00.000045070          Gujarat
# 4                   nodata 1970-01-01 00:00:00.000045070          Gujarat
# ...                    ...                           ...              ...
# 94970     Non-govt company 1983-09-17 00:00:00.000000000          Gujarat
# 94971     Non-govt company 1983-10-10 00:00:00.000000000          Gujarat
# 94972     Non-govt company 1983-10-12 00:00:00.000000000          Gujarat
# 94973     Non-govt company 1983-10-20 00:00:00.000000000          Gujarat
# 94974     Non-govt company 1983-10-20 00:00:00.000000000          Gujarat
#
#        AUTHORIZED_CAP  PAIDUP_CAPITAL  INDUSTRIAL_CLASS  \
# 0                 0.0             0.0      45070.853211
# 1                 0.0             0.0      45070.853211
# 2                 0.0             0.0      45070.853211
# 3                 0.0             0.0      45070.853211
# 4                 0.0             0.0      45070.853211
# ...               ...             ...               ...
# 94970        100000.0             0.0      65910.000000
# 94971        100000.0             0.0      65910.000000
# 94972        300000.0          2000.0      65910.000000
# 94973       2400000.0       2366000.0      65910.000000
# 94974       2400000.0        104000.0      65910.000000
#
#       PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                       Agriculture & allied
# 1                       Agriculture & allied
# 2                       Agriculture & allied
# 3                       Agriculture & allied
# 4                       Agriculture & allied
# ...                                      ...
# 94970               Financial intermediation
# 94971               Financial intermediation
# 94972               Financial intermediation
# 94973               Financial intermediation
# 94974               Financial intermediation
#
#                                REGISTERED_OFFICE_ADDRESS  \
# 0                        4TH FLOOR,LANDMARKRACE COURSE
# 1      403 3 6 322 MAHAVIR HOUSEBUSHEER BAGH HYDERGUD...
# 2      Quadrant 1, Plot Number 18, 2nd FloorSuman Tow...
# 3         Plot No. 3526 & 3527,GIDC Industrial Estate,
# 4                        24 ATMAJYOTI NAGARELLORA PARK
# ...                                                  ...
# 94970  A.C.I. PREMISES,OPP. VIJAYMILLS, NARODA  ROAD,...
# 94971       36,LALDARWAJA,VAKIL CHAMBERS,AHMEDABAD-1.
# 94972  42, EMBASSY MARKET, NEARDINESH HALL ASHRAM ROA...
# 94973  509, 5th FLOOR, SNS ARISTA,OPP. HAPPY RESIDENC...
# 94974                                      SHETH LALBHAI
#
#       REGISTRAR_OF_COMPANIES               EMAIL_ADDR
# 0                  ROC DELHI     SANJAY@NIKOINDIA.COM
# 1                  ROC DELHI                   nodata
# 2                  ROC DELHI          info@nangia.com
# 3                  ROC DELHI  amit.kumashi@solvay.com
# 4                  ROC DELHI                   nodata
# ...                      ...                      ...
# 94970          ROC AHMEDABAD                   nodata
# 94971          ROC AHMEDABAD                   nodata
# 94972          ROC AHMEDABAD                   nodata
# 94973          ROC AHMEDABAD  anvayalalbhai@gmail.com
# 94974                 nodata                   nodata
#
# [94975 rows x 15 columns]
